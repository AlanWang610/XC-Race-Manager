# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("Results.csv")
df.head()
# Out:
#   Gender     Time        First     Last                   School  Bib
# 0      M  25:54.0      Leonard  Cameron  Northeastern University  304
# 1      M  26:44.4  Castronuovo  Vincent  Northeastern University  195
# 2      M  26:49.9      Burford   Andrew   Stony Brook University  323
# 3      M  26:52.6        Hinds   Thomas  Northeastern University  200
# 4      M  26:56.7     Sandifer     Drew           Boston College  110

# %%
dfm = df[df["Gender"] == "M"]
dff = df[df["Gender"] == "F"]

# %%
dfm.sort_values("Time")
dff.sort_values("Time")
# Out:
#     Gender     Time      First      Last  \
# 143      F  23:02.3     Weiner     Shira
# 144      F  23:09.7    Present    Isabel
# 145      F  23:12.6   McCarthy   Kathryn
# 146      F  23:18.7    Dudziak   Juliana
# 147      F  23:28.0    Harding      Lily
# ..     ...      ...        ...       ...
# 228      F  35:03.5  Oguachuba     Peace
# 229      F  35:50.8      Weiss       Zoe
# 230      F  36:14.9    Tamilio    Gianna
# 231      F  36:34.2      Bisio  Caroline
# 232      F  49:53.6      Xiong    Zhirui
#
#                                     School  Bib
# 143                Northeastern University  848
# 144  Massachusetts Institute of Technology  894
# 145                Northeastern University  838
# 146                         Boston College  383
# 147                       Brown University  819
# ..                                     ...  ...
# 228     University of Massachusetts Lowell  885
# 229                     Harvard University  829
# ...

# %%
dfm.insert(len(dfm.columns),"Place",np.arange(1,len(dfm)+1))
dff.insert(len(dff.columns),"Place",np.arange(1,len(dff)+1))

# %%
# Out:
#     Gender     Time        First        Last  \
# 0        M  25:54.0      Leonard     Cameron
# 1        M  26:44.4  Castronuovo     Vincent
# 2        M  26:49.9      Burford      Andrew
# 3        M  26:52.6        Hinds      Thomas
# 4        M  26:56.7     Sandifer        Drew
# ..     ...      ...          ...         ...
# 138      M  40:04.9        Asadi     Cameron
# 139      M  40:56.1    Kunchulia  Aleksander
# 140      M  41:00.5         Howe       Wyatt
# 141      M  41:20.4        Sheer        Erik
# 142      M  42:24.6        Rossi        Ryan
#
#                                  School  Bib  Place
# 0               Northeastern University  304      1
# 1               Northeastern University  195      2
# 2                Stony Brook University  323      3
# 3               Northeastern University  200      4
# 4                        Boston College  110      5
# ..                                  ...  ...    ...
# ...

# %%
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 138    139
# 139    140
# 140    141
# 141    142
# 142    143
# Length: 143, dtype: int32
